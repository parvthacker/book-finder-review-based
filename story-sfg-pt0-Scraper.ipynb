# %% [markdown]
# # Context and Review based Recommender & Generator
# ## <a href = "https://www.kaggle.com/code/parvth/story-sfg-pt0">Part 0 - Crawler and Scraper -  Get Data from the Web</a>
# #### <a href = "https://www.kaggle.com/code/parvth/story-sfg-pt1-2">Part 1 - Vectorizer, and Retrival</a>
# #### <a href = "https://www.kaggle.com/code/parvth/story-sfg-pt2">Part 2 - Generator and Speech Synthethizer</a>
# ---
# **IRS Innovative Assignment (Even 2023-24)** <br>
# **Roll No. and Names:**<br>
# &emsp;21BCE183 Parv Thacker <br>
# &emsp;21BCE201 Kaju Patel <br>
# &emsp;21BCE250 Tanvi Rathod <br>

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Imports

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pandas as pd
import re

# %% [markdown]
# # Modules

# %% [markdown]
# ## Crawler

# %%
def crawl(url, max_pages=100):
    visited = set()  #Track visited URLs
    frontier = [url]  #Frontier - Queue
    page_count = 0
    crawled_urls = []

    while frontier and page_count < max_pages:
        current_url = frontier.pop(0)
        
        if current_url in visited:   # Skip visited
            continue
        visited.add(current_url)
        
        try:
            headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'}
            
            response = requests.get(current_url, headers=headers)
            if response.status_code == 200:
                soup = BeautifulSoup(response.content, 'html.parser')
                
                # Processing Page
                print("Crawling:", current_url)
                crawled_urls.append(current_url)
                
                # Extract links from the page
                links = soup.find_all('a', href=True)
                for link in links:
                    absolute_url = urljoin(current_url, link['href'])
                    
                    # URL Rule - Checks (Robots.txt - Check skipped as only selected urls will be added to frontier)
                    if absolute_url.startswith("https://www.goodreads.com/book/show") or absolute_url.startswith("https://www.goodreads.com/book/similar") or \
                        absolute_url.startswith("https://www.goodreads.com/series/") or absolute_url.startswith("https://www.goodreads.com/author/show" )\
                            or absolute_url.startswith("https://www.goodreads.com/list/show/") or absolute_url.startswith("https://www.goodreads.com/list/book/")  :
                        
                        # Don't add URLs already crawled or are in Frontier Queue
                        if "#" not in absolute_url \
                           and "?review" not in absolute_url and absolute_url not in visited and absolute_url not in frontier:
                            frontier.append(absolute_url)
                
                page_count += 1
            else:
                print("Failed to fetch:", current_url)
        except Exception as e:
            print("Error:", e)
            continue
    
    return crawled_urls

# %% [markdown]
# ## Scraper

# %%
def scrape_reviews(url):
    # URL --> Book ID
    book_id = url.split('/')[-1].split('.')[0]
    
    url_rev = "https://www.goodreads.com/book/show/"+(str)(book_id)+"/reviews"
    print(f"Scraping: {url_rev}")
    response = requests.get(url_rev)
    soup = BeautifulSoup(response.text, 'html.parser')

    reviews = []

    # Finding all review sections
    review_sections = soup.find_all('section', class_='ReviewCard__content')

    # Extract review text and vote count
    for review_section in review_sections:
        # Extracting review text
        review_text = review_section.find('div', class_='TruncatedContent__text').text.strip()

        # Extracting vote count
        vote_count_element = review_section.find('span', class_='Button__labelItem')
        if vote_count_element:
            vote_count_text = vote_count_element.text.strip()
            vote_count = re.findall(r'\d+', vote_count_text)
            if vote_count:
                vote_count = int(vote_count[0])
            else:
                vote_count = 0
        else:
            vote_count = 0

        reviews.append({
            'book_id': book_id,
            'review': review_text,
            'vote_count': vote_count
        })

    return reviews

# %%
def convert_to_int(book_id):
    try:
        return int(book_id)
    except ValueError:
        # If book_id is not a number, check if it starts with a number
        num_part = ''.join(filter(str.isdigit, book_id))
        if num_part:
            return int(num_part)
        else:
            return None  # Return None to drop the record

# %% [markdown]
# # Driver

# %%
crawled_urls = crawl("https://www.goodreads.com/book/show/14935", max_pages=100)
# Out:
# Crawling: https://www.goodreads.com/book/show/14935
# Crawling: https://www.goodreads.com/author/show/1265.Jane_Austen
# Crawling: https://www.goodreads.com/author/show/9321.Ros_Ballaster
# Crawling: https://www.goodreads.com/author/show/3148482._
# Crawling: https://www.goodreads.com/book/show/1885.Pride_and_Prejudice
# Crawling: https://www.goodreads.com/book/show/6969.Emma
# Crawling: https://www.goodreads.com/book/show/14935.Sense_and_Sensibility
# Crawling: https://www.goodreads.com/book/show/45032.Mansfield_Park
# Crawling: https://www.goodreads.com/book/show/50398.Northanger_Abbey
# Crawling: https://www.goodreads.com/book/show/2156.Persuasion
# Crawling: https://www.goodreads.com/book/show/166177.Sanditon
# Crawling: https://www.goodreads.com/book/show/31669.A_Memoir_of_Jane_Austen
# Crawling: https://www.goodreads.com/author/show/18304042.Frances_Burney
# Failed to fetch: https://www.goodreads.com/author/show/285932._Mary_Brunton
# Crawling: https://www.goodreads.com/author/show/22191.Samuel_Johnson
# Crawling: https://www.goodreads.com/book/show/91582.Lady_Susan
# Crawling: https://www.goodreads.com/book/show/14905.The_Complete_Novels
# Crawling: https://www.goodreads.com/book/show/208729.Lady_Susan_The_Watsons_Sanditon
# Crawling: https://www.goodreads.com/author/show/60750.Margaret_Drabble
# Crawling: https://www.goodreads.com/book/show/6693775-pride-and-prejudice-and-zombies
# Crawling: https://www.goodreads.com/author/show/10473.Tony_Lee
# Crawling: https://www.goodreads.com/author/show/101873.Cliff_Richards
# Crawling: https://www.goodreads.com/series/list?id=1265.Jane_Austen
# Crawling: https://www.goodreads.com/series/105318-juvenilia
# Crawling: https://www.goodreads.com/series/81604-supernatural-jane-austen
# Crawling: https://www.goodreads.com/author/show/186145.Vera_Nazarian
# Crawling: https://www.goodreads.com/book/show/17061.Coraline
# Crawling: https://www.goodreads.com/author/show/1221698.Neil_Gaiman
# Crawling: https://www.goodreads.com/book/show/23587115.Spontaneous
# Crawling: https://www.goodreads.com/author/show/355175.Aaron_Starmer
# Crawling: https://www.goodreads.com/book/show/414895.Planet_of_the_Apes
# Crawling: https://www.goodreads.com/author/show/3400721.Pierre_Boulle
# Crawling: https://www.goodreads.com/book/show/32075671.The_Hate_U_Give__The_Hate_U_Give___1_
# Crawling: https://www.goodreads.com/author/show/15049422.Angie_Thomas
# Crawling: https://www.goodreads.com/book/show/16101128.The_5th_Wave__The_5th_Wave___1_
# Crawling: https://www.goodreads.com/author/show/3377941.Rick_Yancey
# Crawling: https://www.goodreads.com/book/show/28194.Inkheart__Inkworld___1_
# Crawling: https://www.goodreads.com/author/show/15873.Cornelia_Funke
# Crawling: https://www.goodreads.com/book/show/19063.The_Book_Thief
#  'https://www.goodreads.com/book/show/32075671.The_Hate_U_Give__The_Hate_U_Give___1_',
#  'https://www.goodreads.com/book/show/16101128.The_5th_Wave__The_5th_Wave___1_',
#  'https://www.goodreads.com/book/show/28194.Inkheart__Inkworld___1_',
#  'https://www.goodreads.com/book/show/19063.The_Book_Thief',
#  'https://www.goodreads.com/book/show/714902.Noughts___Crosses__Noughts___Crosses___1_',
#  'https://www.goodreads.com/book/show/84981.Tuck_Everlasting',
#  'https://www.goodreads.com/book/show/24611765.The_Last_Kids_on_Earth__Last_Kids_on_Earth___1_',
#  'https://www.goodreads.com/book/show/44286501.Lost_in_Space_Return_to_Yesterday',
#  'https://www.goodreads.com/book/show/10194157.Shadow_and_Bone__The_Shadow_and_Bone_Trilogy___1_',
#  'https://www.goodreads.com/book/show/13088498.Nerve',
#  'https://www.goodreads.com/book/show/33574273.A_Wrinkle_in_Time__Time_Quintet___1_',
#  'https://www.goodreads.com/book/show/39939417.Five_Feet_Apart',
#  'https://www.goodreads.com/book/show/78411.The_Bad_Beginning__A_Series_of_Unfortunate_Events___1_',
#  'https://www.goodreads.com/book/show/58679358.One_of_Us_Is_Lying__One_of_Us_is_Lying___1_',
#  'https://www.goodreads.com/book/show/44767458.Dune__Dune___1_',
#  'https://www.goodreads.com/book/show/5129.Brave_New_World',
#  'https://www.goodreads.com/book/show/16054808.Escape_from_Mr__Lemoncello_s_Library__Mr__Lemoncello_s_Library__1_',
#  'https://www.goodreads.com/book/show/8127.Anne_of_Green_Gables__Anne_of_Green_Gables___1_',
#  'https://www.goodreads.com/book/show/606928.The_Case_of_the_Missing_Marquess__Enola_Holmes___1_',
#  'https://www.goodreads.com/book/show/444304.The_Field_Guide__The_Spiderwick_Chronicles___1_',
#  'https://www.goodreads.com/book/show/1656001.The_Host__The_Host___1_',
#  'https://www.goodreads.com/book/show/35603805.Nightbooks',
#  'https://www.goodreads.com/book/show/25953369.Hidden_Figures',
#  'https://www.goodreads.com/book/show/49822845.Book_One_Moon__The_Dragon_Prince__1_',
#  'https://www.goodreads.com/book/show/3636.The_Giver__The_Giver___1_',
#  'https://www.goodreads.com/book/show/57736.Shoeless_Joe',
#  'https://www.goodreads.com/book/show/386162.The_Hitchhiker_s_Guide_to_the_Galaxy__Hitchhiker_s_Guide_to_the_Galaxy___1_',
#  'https://www.goodreads.com/book/show/295801.The_House_with_a_Clock_in_Its_Walls',
#  'https://www.goodreads.com/book/show/162085.Pretty_Little_Liars__Pretty_Little_Liars___1_',
#  'https://www.goodreads.com/book/show/39280444.Speak',
#  'https://www.goodreads.com/book/show/15749186.To_All_the_Boys_I_ve_Loved_Before__To_All_the_Boys_I_ve_Loved_Before___1_',
#  'https://www.goodreads.com/book/show/10576365.The_Darkest_Minds__The_Darkest_Minds___1_',
#  'https://www.goodreads.com/book/show/23197600.Gabby_Duran_and_the_Unsittables',
#  'https://www.goodreads.com/book/show/24998996.Upside_Down_Magic__Upside_Down_Magic___1_']

# %%
urls = filtered_urls

# Scrape reviews --> dictionaries
all_reviews = []
for url in urls:
